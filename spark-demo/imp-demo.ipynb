# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, desc, sum, avg
# Initialize
spark = SparkSession.builder.appName("ImportFileApp").getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/06/12 05:55:50 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/06/12 05:55:52 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
df = spark.read \
    .option("header", True) \
    .csv("output/employees")

# %%
df.show()
# Out:
# +---+-------+-----------+------+---+
# | Id|   Name| Department|Salary|Age|
# +---+-------+-----------+------+---+
# |  3|Charlie|Engineering| 80000| 35|
# |  4|  David|      Sales| 65000| 28|
# |  5|    Eve|  Marketing| 70000| 32|
# |  1|  Alice|Engineering| 75000| 25|
# |  2|    Bob|  Marketing| 60000| 30|
# +---+-------+-----------+------+---+

# %%
df.createOrReplaceTempView("employees")

# %%
result = spark.sql("""SELECT * FROM employees WHERE Salary > 70000""").show()
# Out:
# +---+-------+-----------+------+---+
# | Id|   Name| Department|Salary|Age|
# +---+-------+-----------+------+---+
# |  3|Charlie|Engineering| 80000| 35|
# |  1|  Alice|Engineering| 75000| 25|
# +---+-------+-----------+------+---+
